# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('telco.csv')
df.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                  0     Yes        Yes              1
# 1  0003-MKNFE    Male                  0      No         No              2
# 2  0004-TLHLJ    Male                  0      No         No              1
# 3  0011-IGKFF    Male                  1     Yes         No              1
# 4  0013-EXCHZ  Female                  1     Yes         No              1
#
#    internet_service  contract_type      payment_type  monthly_charges  ...  \
# 0                 1              1      Mailed check             65.6  ...
# 1                 1              0      Mailed check             59.9  ...
# 2                 2              0  Electronic check             73.9  ...
# 3                 2              0  Electronic check             98.0  ...
# 4                 2              0      Mailed check             83.9  ...
#
# ...

# %%
df.contract_type.value_counts(dropna=False)
# Out:
# 0    3876
# 2    1697
# 1    1476
# Name: contract_type, dtype: int64

# %%
df['Contract Type'].value_counts(dropna=False)
# Out:
# 3                 6154
# Month-to-Month     475
# 2 Year             226
# 1 Year             194
# Name: Contract Type, dtype: int64

# %%
df[df['Contract Type'] == '3']
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 895   1304-BCCFO    Male                  0     Yes         No              1
# 896   1304-NECVQ  Female                  1      No         No              2
# 897   1304-SEGFY  Female                  0     Yes         No              2
# 898   1306-RPWXZ  Female                  0      No        Yes              1
# 899   1307-ATKGB    Male                  0      No         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044         NaN  Female                  0      No         No              1
# 7045         NaN    Male                  0     Yes         No              2
# 7046         NaN    Male                  0      No         No              1
# 7047         NaN    Male                  0     Yes        Yes              1
# 7048         NaN    Male                  0     Yes        Yes              0
#
# ...
